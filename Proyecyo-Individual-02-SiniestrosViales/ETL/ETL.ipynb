# %% [markdown]
# ## ETL

# %% [markdown]
# Iniciamos la extracción, transformación y carga de nuestros datos. Nos dirigimos hacía un enfoque, donde la data que procesemos, nos ayuda en el desarrollo de nuestros kpi´s, así como en la exploración estadistica.

# %%
#Importamos las librerías que usaremos
import pandas as pd  
import numpy as np
import datetime

# %% [markdown]
# Funciones utilizadas

# %%
def encontrar_datos_nulos(dataframe):
    # Verificar la presencia de valores nulos en el DataFrame
    datos_nulos = dataframe.isnull()

    # Contar la cantidad de valores nulos en cada columna
    resumen_nulos = datos_nulos.sum()

    # Filtrar las columnas que tienen al menos un valor nulo
    columnas_con_nulos = resumen_nulos[resumen_nulos > 0]

    # Imprimir el resumen
    print("Resumen de datos nulos:")
    if columnas_con_nulos.empty:
        print("No hay datos nulos en el DataFrame.")
    else:
        print(columnas_con_nulos)


def eliminar_nulos(dataframe):
    # Eliminar todos los registros que contienen al menos un valor NaN
    dataframe_sin_nan = dataframe.dropna(axis=0)

    return dataframe_sin_nan

def eliminar_columnas(dataframe, columnas_a_eliminar):
    # Eliminar las columnas especificadas
    dataframe_sin_columnas = dataframe.drop(columnas_a_eliminar, axis=1, inplace=False)

    return dataframe_sin_columnas

def convertir_columna_float_a_int(dataframe, nombre_columna):
    # Verificar si la columna existe en el DataFrame
    if nombre_columna not in dataframe.columns:
        print(f"La columna '{nombre_columna}' no existe en el DataFrame.")
        return dataframe

    # Convertir la columna de float a int y reemplazar los valores nulos con 0
    dataframe[nombre_columna] = dataframe[nombre_columna].fillna(0).astype(int)

def porcentaje_datos_nulos_por_columna(dataframe):
    """
    Calcula el porcentaje de datos nulos por columna en un DataFrame.

    Parámetros:
    - dataframe: DataFrame de pandas

    Retorna:
    - Un DataFrame que muestra el porcentaje de datos nulos por columna
    """
    # Calcular el porcentaje de datos nulos por columna
    porcentaje_nulos = (dataframe.isnull().sum() / len(dataframe)) * 100

    # Crear un nuevo DataFrame con los resultados
    resultado = pd.DataFrame({'Columna': dataframe.columns, 'Porcentaje_Nulos': porcentaje_nulos})

    return resultado

# %% [markdown]
# Cargamos nuestros archivos

# %%
#Nota: en excle se cargaron los archivos para una exploración preliminar, encontrando datos nulos como SD, sd, SD-SD entre otros
# Definir nombres de archivos y hojas de cálculo
archivo_homicidios = '../DatosCrudos/homicidios.xlsx'
archivo_lesiones = '../DatosCrudos/lesiones.xlsx'
hoja_hechos = 'HECHOS'
hoja_victimas = 'VICTIMAS'
valores_nulos = ['SD', 'sd']

# Cargar los archivos
homicidios = pd.read_excel(archivo_homicidios, sheet_name=hoja_hechos, na_values=valores_nulos)
vic_hom = pd.read_excel(archivo_homicidios, sheet_name=hoja_victimas, na_values=valores_nulos)
lesiones = pd.read_excel(archivo_lesiones, sheet_name=hoja_hechos, na_values=valores_nulos)
vic_les = pd.read_excel(archivo_lesiones, sheet_name=hoja_victimas, na_values=valores_nulos)

# %% [markdown]
# Comenzaremos limpiando los archivos df_homicidios y df_vic_hom, ya que pertenecen al mismo archivo

# %%
vic_hom
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0    2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1    2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2    2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3    2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4    2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# ..         ...        ...   ...  ..  ..                   ...     ...
# 712  2021-0092 2021-12-12  2021  12  12                PEATON  PEATON
# 713  2021-0093 2021-12-13  2021  12  13  PASAJERO_ACOMPAÑANTE    MOTO
# 714  2021-0094 2021-12-20  2021  12  20  PASAJERO_ACOMPAÑANTE    MOTO
# 715  2021-0095 2021-12-30  2021  12  30             CONDUCTOR    MOTO
# 716  2021-0096 2021-12-15  2021  12  15             CONDUCTOR    AUTO
#
#           SEXO  EDAD  FECHA_FALLECIMIENTO
# 0    MASCULINO  19.0  2016-01-01 00:00:00
# 1    MASCULINO  70.0  2016-01-02 00:00:00
# 2    MASCULINO  30.0  2016-01-03 00:00:00
# 3    MASCULINO  18.0                  NaN
# 4    MASCULINO  29.0  2016-02-01 00:00:00
# ..         ...   ...                  ...
# 712   FEMENINO  50.0  2021-12-12 00:00:00
# 713   FEMENINO  18.0  2021-12-18 00:00:00
# 714   FEMENINO  43.0  2021-12-20 00:00:00
# 715  MASCULINO  27.0  2022-01-02 00:00:00
# 716  MASCULINO  60.0  2021-12-20 00:00:00
#
# [717 rows x 10 columns]

# %%
homicidios
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA    HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4.0
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1.0
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7.0
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0.0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5.0
# ..         ...         ...        ...   ...  ..  ..       ...   ...
# 691  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17.0
# 692  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1.0
# 693  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0.0
# 694  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10.0
# 695  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6.0
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1            AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                           AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3        AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4    AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
# ..                                         ...           ...  ...     ...
# 691                          AV. RIESTRA Y MOM       AVENIDA  ...     NaN
# 692                    AU DELLEPIANE Y LACARRA     AUTOPISTA  ...     NaN
# 693                        AV. GAONA Y TERRADA       AVENIDA  ...     NaN
# 694                         AV. EVA PERON 4071       AVENIDA  ...  4071.0
# 695                    PADRE CARLOS MUJICA 709         CALLE  ...   709.0
#
#                                    Cruce  \
# 0    FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                    DE LOS CORRALES AV.
# 2                                    NaN
# 3               VILLEGAS, CONRADO, GRAL.
# 4                SAENZ PE?A, LUIS, PRES.
# ..                                   ...
# 691                                  MOM
# 692                          LACARRA AV.
# 693                              TERRADA
# 694                                  NaN
# 695                                  NaN
#
#                                  Dirección Normalizada COMUNA  \
# 0    PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1                 PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                  ENTRE RIOS AV. 2034      1
# 3            LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4              SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
# ..                                                 ...    ...
# 691                                  RIESTRA AV. y MOM      7
# 692         DELLEPIANE, LUIS, TTE. GRAL. y LACARRA AV.      9
# 693                                GAONA AV. y TERRADA     11
# 694                                PERON, EVA AV. 4071      9
# 695                            PADRE CARLOS MUGICA 709      1
#
#                                    XY (CABA)         pos x         pos y  \
# 0      Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1      Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2     Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3      Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4    Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# ..                                       ...           ...           ...
# 691   Point (102728.60090138 98186.24929177)  -58.43353773  -34.64561636
# 692    Point (99624.29795829 97569.69801131)  -58.46739825  -34.65117757
# 693   Point (99116.45492358 101045.23284826)  -58.47293407  -34.61984745
# 694    Point (99324.54463985 97676.26932409)  -58.47066794  -34.65021673
# 695  Point (107664.16647795 104708.63962087)  -58.37976155  -34.58679619
#
#       PARTICIPANTES    VICTIMA    ACUSADO
# 0         MOTO-AUTO       MOTO       AUTO
# 1    AUTO-PASAJEROS       AUTO  PASAJEROS
# 2         MOTO-AUTO       MOTO       AUTO
# 3           MOTO-SD       MOTO        NaN
# 4    MOTO-PASAJEROS       MOTO  PASAJEROS
# ..              ...        ...        ...
# 691       MOTO-AUTO       MOTO       AUTO
# 692       MOTO-AUTO       MOTO       AUTO
# 693     MOTO-CARGAS       MOTO     CARGAS
# 694     AUTO-CARGAS       AUTO     CARGAS
# 695  BICICLETA-AUTO  BICICLETA       AUTO
#
# [696 rows x 21 columns]

# %% [markdown]
# Analizamos los tipos de datos

# %%
homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   695 non-null    object
#  7   HH                     695 non-null    float64
#  8   LUGAR_DEL_HECHO        695 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  688 non-null    object
#  14  COMUNA                 696 non-null    int64
#  15  XY (CABA)              696 non-null    object
#  16  pos x                  696 non-null    object
#  17  pos y                  696 non-null    object
#  18  PARTICIPANTES          696 non-null    object
#  19  VICTIMA                687 non-null    object
#  20  ACUSADO                673 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(13)
# memory usage: 114.3+ KB

# %%
encontrar_datos_nulos(homicidios) #Probamos nuestra función
# Out:
# Resumen de datos nulos:
# HORA                       1
# HH                         1
# LUGAR_DEL_HECHO            1
# Calle                      1
# Altura                   567
# Cruce                    171
# Dirección Normalizada      8
# VICTIMA                    9
# ACUSADO                   23
# dtype: int64

# %% [markdown]
# ## Con este analisis en mente, comenzaremos la limpieza del primer archivo

# %% [markdown]
# Se puede asumir que SD en este dataframe es sin dato, por ende, nulo. Por lo que procedemos a cambiar los SD por nulos. De igual manera, en la columna COMUNA procedemos con los 0.

# %%
# Reemplazar "SD" por np.nan en todo el DataFrame
homicidios.replace("SD", np.nan, inplace=True)
homicidios.replace("SD-SD", np.nan, inplace=True)

# remplazar la comuna 0 a nulos
homicidios.loc[homicidios['COMUNA'] == '0' ,'COMUNA'] = np.nan


# remplazar los "." por nulos en latitud y longitud
homicidios.loc[homicidios['pos x'] == '.' ,'pos x'] = np.nan
homicidios.loc[homicidios['pos y'] == '.' ,'pos y'] = np.nan
homicidios.loc[homicidios['XY (CABA)'] == 'Point (. .)' ,'XY (CABA)'] = np.nan

# %%
homicidios
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA    HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4.0
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1.0
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7.0
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0.0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5.0
# ..         ...         ...        ...   ...  ..  ..       ...   ...
# 691  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17.0
# 692  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1.0
# 693  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0.0
# 694  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10.0
# 695  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6.0
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1            AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                           AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3        AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4    AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
# ..                                         ...           ...  ...     ...
# 691                          AV. RIESTRA Y MOM       AVENIDA  ...     NaN
# 692                    AU DELLEPIANE Y LACARRA     AUTOPISTA  ...     NaN
# 693                        AV. GAONA Y TERRADA       AVENIDA  ...     NaN
# 694                         AV. EVA PERON 4071       AVENIDA  ...  4071.0
# 695                    PADRE CARLOS MUJICA 709         CALLE  ...   709.0
#
#                                    Cruce  \
# 0    FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                    DE LOS CORRALES AV.
# 2                                    NaN
# 3               VILLEGAS, CONRADO, GRAL.
# 4                SAENZ PE?A, LUIS, PRES.
# ..                                   ...
# 691                                  MOM
# 692                          LACARRA AV.
# 693                              TERRADA
# 694                                  NaN
# 695                                  NaN
#
#                                  Dirección Normalizada COMUNA  \
# 0    PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...    8.0
# 1                 PAZ, GRAL. AV. y DE LOS CORRALES AV.    9.0
# 2                                  ENTRE RIOS AV. 2034    1.0
# 3            LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.    8.0
# 4              SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.    1.0
# ..                                                 ...    ...
# 691                                  RIESTRA AV. y MOM    7.0
# 692         DELLEPIANE, LUIS, TTE. GRAL. y LACARRA AV.    9.0
# 693                                GAONA AV. y TERRADA   11.0
# 694                                PERON, EVA AV. 4071    9.0
# 695                            PADRE CARLOS MUGICA 709    1.0
#
#                                    XY (CABA)         pos x         pos y  \
# 0      Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1      Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2     Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3      Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4    Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# ..                                       ...           ...           ...
# 691   Point (102728.60090138 98186.24929177)  -58.43353773  -34.64561636
# 692    Point (99624.29795829 97569.69801131)  -58.46739825  -34.65117757
# 693   Point (99116.45492358 101045.23284826)  -58.47293407  -34.61984745
# 694    Point (99324.54463985 97676.26932409)  -58.47066794  -34.65021673
# 695  Point (107664.16647795 104708.63962087)  -58.37976155  -34.58679619
#
#       PARTICIPANTES    VICTIMA    ACUSADO
# 0         MOTO-AUTO       MOTO       AUTO
# 1    AUTO-PASAJEROS       AUTO  PASAJEROS
# 2         MOTO-AUTO       MOTO       AUTO
# 3           MOTO-SD       MOTO        NaN
# 4    MOTO-PASAJEROS       MOTO  PASAJEROS
# ..              ...        ...        ...
# 691       MOTO-AUTO       MOTO       AUTO
# 692       MOTO-AUTO       MOTO       AUTO
# 693     MOTO-CARGAS       MOTO     CARGAS
# 694     AUTO-CARGAS       AUTO     CARGAS
# 695  BICICLETA-AUTO  BICICLETA       AUTO
#
# [696 rows x 21 columns]

# %% [markdown]
# Tratamos los datos categoricos

# %%
#Convertimos las columnas a tipo categorico
categorical_columns = ['HH', 'TIPO_DE_CALLE', 'COMUNA', 'ACUSADO']
homicidios[categorical_columns] = homicidios[categorical_columns].astype('category')

#convertimos 'pos x' y 'pos y' en numerico
numeric_columns = ['pos x', 'pos y']
homicidios[numeric_columns] = homicidios[numeric_columns].astype('float')

# %%
#Buscamos nulos con una de nuestras funciones 
encontrar_datos_nulos(homicidios)
# Out:
# Resumen de datos nulos:
# HORA                       1
# HH                         1
# LUGAR_DEL_HECHO            1
# Calle                      1
# Altura                   567
# Cruce                    171
# Dirección Normalizada      8
# XY (CABA)                 14
# pos x                     12
# pos y                     12
# PARTICIPANTES              5
# VICTIMA                    9
# ACUSADO                   23
# dtype: int64

# %%
homicidios
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA    HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4.0
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1.0
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7.0
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0.0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5.0
# ..         ...         ...        ...   ...  ..  ..       ...   ...
# 691  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17.0
# 692  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1.0
# 693  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0.0
# 694  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10.0
# 695  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6.0
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1            AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                           AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3        AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4    AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
# ..                                         ...           ...  ...     ...
# 691                          AV. RIESTRA Y MOM       AVENIDA  ...     NaN
# 692                    AU DELLEPIANE Y LACARRA     AUTOPISTA  ...     NaN
# 693                        AV. GAONA Y TERRADA       AVENIDA  ...     NaN
# 694                         AV. EVA PERON 4071       AVENIDA  ...  4071.0
# 695                    PADRE CARLOS MUJICA 709         CALLE  ...   709.0
#
#                                    Cruce  \
# 0    FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                    DE LOS CORRALES AV.
# 2                                    NaN
# 3               VILLEGAS, CONRADO, GRAL.
# 4                SAENZ PE?A, LUIS, PRES.
# ..                                   ...
# 691                                  MOM
# 692                          LACARRA AV.
# 693                              TERRADA
# 694                                  NaN
# 695                                  NaN
#
#                                  Dirección Normalizada COMUNA  \
# 0    PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...    8.0
# 1                 PAZ, GRAL. AV. y DE LOS CORRALES AV.    9.0
# 2                                  ENTRE RIOS AV. 2034    1.0
# 3            LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.    8.0
# 4              SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.    1.0
# ..                                                 ...    ...
# 691                                  RIESTRA AV. y MOM    7.0
# 692         DELLEPIANE, LUIS, TTE. GRAL. y LACARRA AV.    9.0
# 693                                GAONA AV. y TERRADA   11.0
# 694                                PERON, EVA AV. 4071    9.0
# 695                            PADRE CARLOS MUGICA 709    1.0
#
#                                    XY (CABA)      pos x      pos y  \
# 0      Point (98896.78238426 93532.43437792) -58.475340 -34.687570
# 1      Point (95832.05571093 95505.41641999) -58.508775 -34.669777
# 2     Point (106684.29090040 99706.57687843) -58.390403 -34.631894
# 3      Point (99840.65224780 94269.16534422) -58.465039 -34.680930
# 4    Point (106980.32827929 100752.16915795) -58.387183 -34.622466
# ..                                       ...        ...        ...
# 691   Point (102728.60090138 98186.24929177) -58.433538 -34.645616
# 692    Point (99624.29795829 97569.69801131) -58.467398 -34.651178
# 693   Point (99116.45492358 101045.23284826) -58.472934 -34.619847
# 694    Point (99324.54463985 97676.26932409) -58.470668 -34.650217
# 695  Point (107664.16647795 104708.63962087) -58.379762 -34.586796
#
#       PARTICIPANTES    VICTIMA    ACUSADO
# 0         MOTO-AUTO       MOTO       AUTO
# 1    AUTO-PASAJEROS       AUTO  PASAJEROS
# 2         MOTO-AUTO       MOTO       AUTO
# 3           MOTO-SD       MOTO        NaN
# 4    MOTO-PASAJEROS       MOTO  PASAJEROS
# ..              ...        ...        ...
# 691       MOTO-AUTO       MOTO       AUTO
# 692       MOTO-AUTO       MOTO       AUTO
# 693     MOTO-CARGAS       MOTO     CARGAS
# 694     AUTO-CARGAS       AUTO     CARGAS
# 695  BICICLETA-AUTO  BICICLETA       AUTO
#
# [696 rows x 21 columns]

# %% [markdown]
# Después hacemos una purga. Para nuestro proposito, las columnas 'FECHA', 'DD', 'HORA', 'LUGAR_DEL_HECHO', 'Calle', 'Altura', 'Cruce', 'Dirección Normalizada', no nos sirven

# %%
columnas_a_eliminar=['FECHA', 'DD', 'HORA', 'LUGAR_DEL_HECHO', 'Calle', 'Altura', 'Cruce']

# %% [markdown]
# Para reducir la cantidad de accidentes mortales para motocicletas en un 7% son datos necesarios 'PARTICIPANTES', 'VICTIMAS', 'ACUSADOS' así como la columna 'MM' para nuestro analisis estadistico.
# A su vez para reducir en un 10% la tasa de homicidios en siniestros viales de los últimos seis meses, en CABA, en comparación con la tasa de homicidios en siniestros viales del semestre anterior, necesitamos las columnas antes mencionadas. Haciendo un hincapie en la columna 'MM'.

# %%
#Aplicamos nuestra función 
homicidiosLimpio=eliminar_columnas(homicidios, columnas_a_eliminar)

# %% [markdown]
# De esta manera, concluimos el tratamiento de nulo. Es momento de analizar los tipos de datos

# %%
homicidiosLimpio.tail(2)
# Out:
#             ID  N_VICTIMAS  AAAA  MM    HH TIPO_DE_CALLE  \
# 694  2021-0096           1  2021  12  10.0       AVENIDA
# 695  2021-0097           1  2021  11   6.0         CALLE
#
#        Dirección Normalizada COMUNA                                XY (CABA)  \
# 694      PERON, EVA AV. 4071    9.0    Point (99324.54463985 97676.26932409)
# 695  PADRE CARLOS MUGICA 709    1.0  Point (107664.16647795 104708.63962087)
#
#          pos x      pos y   PARTICIPANTES    VICTIMA ACUSADO
# 694 -58.470668 -34.650217     AUTO-CARGAS       AUTO  CARGAS
# 695 -58.379762 -34.586796  BICICLETA-AUTO  BICICLETA    AUTO

# %%
#Iniciamos con otro informe, teniendo en cuenta nuestro objetivo final
homicidiosLimpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   AAAA                   696 non-null    int64
#  3   MM                     696 non-null    int64
#  4   HH                     695 non-null    category
#  5   TIPO_DE_CALLE          696 non-null    category
#  6   Dirección Normalizada  688 non-null    object
#  7   COMUNA                 696 non-null    category
#  8   XY (CABA)              682 non-null    object
#  9   pos x                  684 non-null    float64
#  10  pos y                  684 non-null    float64
#  11  PARTICIPANTES          691 non-null    object
#  12  VICTIMA                687 non-null    object
#  13  ACUSADO                673 non-null    category
# dtypes: category(4), float64(2), int64(3), object(5)
# memory usage: 59.2+ KB

# %% [markdown]
# Ahora procedemos con el segundo

# %%
vic_hom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   FECHA                717 non-null    datetime64[ns]
#  2   AAAA                 717 non-null    int64
#  3   MM                   717 non-null    int64
#  4   DD                   717 non-null    int64
#  5   ROL                  706 non-null    object
#  6   VICTIMA              708 non-null    object
#  7   SEXO                 711 non-null    object
#  8   EDAD                 664 non-null    float64
#  9   FECHA_FALLECIMIENTO  649 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 56.1+ KB

# %%
# Definir las columnas a eliminar
columnas_a_eliminar = ['AAAA', 'MM', 'DD', 'FECHA_FALLECIMIENTO']

# Eliminar columnas no deseadas
vic_hom.drop(columns=columnas_a_eliminar, inplace=True)

# %%
# Crear una columna con la condición 'GRAVEDAD' igual a 'FATAL'
vic_hom['GRAVEDAD'] = 'FATAL'

# %% [markdown]
# ## ETL - Victimas

# %% [markdown]
# Luego de una limpieza en nuestro primer archivo, es hora de limpiar nuestro segundo archivo, siempre teniendo en mente el producto final

# %%
#Exploramos nuestro archivo
lesiones.tail(15)
# Out:
#                     id  n_victimas  aaaa  mm  dd                fecha  \
# 23770  LC-2021-0652171           1  2021  12  31  2021-12-31 00:00:00
# 23771  LC-2021-0652203           2  2021  12  31  2021-12-31 00:00:00
# 23772  LC-2021-0652278           1  2021  12  31  2021-12-31 00:00:00
# 23773  LC-2021-0652316           5  2021  12  31  2021-12-31 00:00:00
# 23774  LC-2021-0652398           1  2021  12  31  2021-12-31 00:00:00
# 23775  LC-2021-0652473           1  2021  12  31  2021-12-31 00:00:00
# 23776  LC-2021-0652565           1  2021  12  31  2021-12-31 00:00:00
# 23777  LC-2021-0652677           1  2021  12  31  2021-12-31 00:00:00
# 23778  LC-2021-0652681           1  2021  12  31  2021-12-31 00:00:00
# 23779  LC-2021-0652812           1  2021  12  31  2021-12-31 00:00:00
# 23780  LC-2021-0652849           1  2021  12  31  2021-12-31 00:00:00
# 23781  LC-2021-0652865           2  2021  12  31  2021-12-31 00:00:00
# 23782  LC-2021-0652907           1  2021  12  31  2021-12-31 00:00:00
# 23783  LC-2021-0652921           1  2021  12  31  2021-12-31 00:00:00
# 23784  LC-2020-0244615           1  2020   5  17            5/17/2020
#
#            hora  franja_hora                          direccion_normalizada  \
# 23770  05:15:00          5.0       CORDOBA AV. y SCALABRINI ORTIZ, RAUL AV.
# 23771  07:00:00          7.0                         YATAY y DIAZ VELEZ AV.
# 23772  08:25:00          8.0                                            NaN
# 23773  09:00:00          9.0                3 DE FEBRERO y PEDRAZA, MANUELA
# 23774  08:45:00          8.0                   MEXICO y SANTIAGO DEL ESTERO
# 23775  10:30:00         10.0          FIGUEROA ALCORTA, PRES. AV. y AUSTRIA
# 23776  11:10:00         11.0                            RIVADAVIA AV. 11500
# 23777  13:10:00         13.0                      MORENO, JOSE MARIA AV. 63
# 23778  14:00:00         14.0  BELAUSTEGUI, LUIS, DR. y GONZALEZ, JOAQUIN V.
# 23779  18:05:00         18.0                                       VIEL 276
# 23780  19:30:00         19.0           ALBERDI, JUAN BAUTISTA AV. y GUAMINI
# 23781  19:40:00         19.0                ALBERDI, JUAN BAUTISTA AV. 4436
# 23782  20:00:00         20.0                                            NaN
# 23783  22:00:00         22.0                        LINIERS VIRREY y MORENO
# 23784  21:00:00         21.0                                            NaN
#
#       comuna  ...       latutid victima             acusado  \
# 23770     15  ... -3.459430e+01     NaN                 NaN
# 23771      5  ... -3.460873e+01     NaN                 NaN
# 23772    NaN  ...           NaN     NaN                 NaN
# 23773     13  ... -3.454839e+01    AUTO                 NaN
# 23774      1  ... -3.461544e+01     NaN                 NaN
# 23775      2  ... -3.458168e+01     NaN                 NaN
# 23776      9  ... -3.463932e+01     NaN                 NaN
# 23777      6  ... -3.461903e+01     NaN                 NaN
# 23778     11  ... -3.462188e+01     NaN                 NaN
# 23779      6  ... -3.461970e+01     NaN                 NaN
# 23780      9  ... -3.465971e+01     NaN                 NaN
# 23781      9  ... -3.464175e+01     NaN                 NaN
# 23782      1  ... -3.458308e+01     NaN                 NaN
# 23783      5  ... -3.461429e+01    MOTO  TRANSPORTE PUBLICO
# 23784    NaN  ... -3.472891e+09    MOTO                AUTO
#
#                  participantes moto auto  transporte_publico  camion ciclista  \
# 23770                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23771                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23772                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23773                  AUTO-SD  NaN    x                 NaN     NaN      NaN
# 23774                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23775                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23776                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23777                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23778                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23779                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23780                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23781                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23782                    SD-SD  NaN  NaN                 NaN     NaN      NaN
# 23783  MOTO-TRANSPORTE PUBLICO    x    0                   x       0        0
# 23784                MOTO-AUTO    x    x                   0       0        0
#
#       gravedad
# 23770      NaN
# 23771      NaN
# 23772      NaN
# 23773      NaN
# 23774      NaN
# 23775      NaN
# 23776      NaN
# 23777      NaN
# 23778      NaN
# 23779      NaN
# 23780      NaN
# 23781      NaN
# 23782      NaN
# 23783    GRAVE
# 23784      NaN
#
# [15 rows x 27 columns]

# %% [markdown]
# Podemos notar, como en el archivo anterior, SD, SD-SD, x entre otros representan los datos nulos. Procedemos, con esto en mente, a cambiar estos datos a NaN para proseguir con la limpieza y tratamientos de nulos

# %%
# Lista de valores a considerar como nulos
valores_nulos = ['SD', 'SD-SD', 'x', 0, 0.0]

# Reemplazar los valores indicados con NaN
lesiones.replace(valores_nulos, np.nan, inplace=True)

# %%
lesiones
# Out:
#                     id  n_victimas  aaaa  mm  dd                fecha  \
# 0      LC-2019-0000179         1.0  2019   1   1  2019-01-01 00:00:00
# 1      LC-2019-0000053         1.0  2019   1   1  2019-01-01 00:00:00
# 2      LC-2019-0000063         1.0  2019   1   1  2019-01-01 00:00:00
# 3      LC-2019-0000079         1.0  2019   1   1  2019-01-01 00:00:00
# 4      LC-2019-0000082         4.0  2019   1   1  2019-01-01 00:00:00
# ...                ...         ...   ...  ..  ..                  ...
# 23780  LC-2021-0652849         1.0  2021  12  31  2021-12-31 00:00:00
# 23781  LC-2021-0652865         2.0  2021  12  31  2021-12-31 00:00:00
# 23782  LC-2021-0652907         1.0  2021  12  31  2021-12-31 00:00:00
# 23783  LC-2021-0652921         1.0  2021  12  31  2021-12-31 00:00:00
# 23784  LC-2020-0244615         1.0  2020   5  17            5/17/2020
#
#            hora  franja_hora                 direccion_normalizada comuna  \
# 0      09:00:00          9.0                                   NaN     14
# 1      01:55:00          1.0                                   NaN      8
# 2      02:00:00          2.0                                   NaN      8
# 3      02:30:00          2.0                                   NaN      7
# 4      04:30:00          4.0                                   NaN      3
# ...         ...          ...                                   ...    ...
# 23780  19:30:00         19.0  ALBERDI, JUAN BAUTISTA AV. y GUAMINI      9
# 23781  19:40:00         19.0       ALBERDI, JUAN BAUTISTA AV. 4436      9
# 23782  20:00:00         20.0                                   NaN      1
# 23783  22:00:00         22.0               LINIERS VIRREY y MORENO      5
# 23784  21:00:00         21.0                                   NaN    NaN
#
#        ...       latutid   victima             acusado  \
# 0      ... -3.455966e+01  CICLISTA                 NaN
# 1      ... -3.466913e+01      AUTO                 NaN
# 2      ... -3.467756e+01       NaN                 NaN
# 3      ... -3.464735e+01    PEATON                 NaN
# 4      ... -3.460458e+01      AUTO                 NaN
# ...    ...           ...       ...                 ...
# 23780  ... -3.465971e+01       NaN                 NaN
# 23781  ... -3.464175e+01       NaN                 NaN
# 23782  ... -3.458308e+01       NaN                 NaN
# 23783  ... -3.461429e+01      MOTO  TRANSPORTE PUBLICO
# 23784  ... -3.472891e+09      MOTO                AUTO
#
#                  participantes moto auto  transporte_publico  camion ciclista  \
# 0                  CICLISTA-SD  NaN  NaN                 NaN     NaN      NaN
# 1                      AUTO-SD  NaN  NaN                 NaN     NaN      NaN
# 2                          NaN  NaN  NaN                 NaN     NaN      NaN
# 3                    PEATON-SD  NaN  NaN                 NaN     NaN      NaN
# 4                      AUTO-SD  NaN  NaN                 NaN     NaN      NaN
# ...                        ...  ...  ...                 ...     ...      ...
# 23780                      NaN  NaN  NaN                 NaN     NaN      NaN
# 23781                      NaN  NaN  NaN                 NaN     NaN      NaN
# 23782                      NaN  NaN  NaN                 NaN     NaN      NaN
# 23783  MOTO-TRANSPORTE PUBLICO  NaN  NaN                 NaN     NaN      NaN
# 23784                MOTO-AUTO  NaN  NaN                 NaN     NaN      NaN
#
#       gravedad
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 23780      NaN
# 23781      NaN
# 23782      NaN
# 23783    GRAVE
# 23784      NaN
#
# [23785 rows x 27 columns]

# %% [markdown]
# Después de este pequeño analisis, procedemos a eliminar las columnas innecesarias

# %%
#Eliminar las columnas que no son importantes
columnas_a_eliminar = ['aaaa', 'mm', 'dd', 'hora', 'direccion_normalizada',
                        'calle', 'altura', 'cruce', 'participantes', 'moto',
                        'auto', 'transporte_publico', 'camion', 'otra_direccion',
                        'ciclista', 'victima']

lesiones.drop(columns=columnas_a_eliminar, inplace=True)

# %% [markdown]
# Hacemos ahora un conteo de los datos nulos

# %%
encontrar_datos_nulos(lesiones)
# Out:
# Resumen de datos nulos:
# n_victimas                  1
# franja_hora               816
# comuna                   1015
# tipo_calle              11045
# geocodificacion_CABA     1252
# longitud                 1471
# latutid                  1471
# acusado                 15288
# gravedad                23139
# dtype: int64

# %% [markdown]
# Aplicamos mi función para analizar el porcentaje

# %%
porcentaje_datos_nulos_por_columna(lesiones)
# Out:
#                                    Columna  Porcentaje_Nulos
# id                                      id          0.000000
# n_victimas                      n_victimas          0.004204
# fecha                                fecha          0.000000
# franja_hora                    franja_hora          3.430734
# comuna                              comuna          4.267395
# tipo_calle                      tipo_calle         46.436830
# geocodificacion_CABA  geocodificacion_CABA          5.263822
# longitud                          longitud          6.184570
# latutid                            latutid          6.184570
# acusado                            acusado         64.275804
# gravedad                          gravedad         97.284003

# %%
# Pasar las columnas a mayusculas
lesiones.columns = lesiones.columns.str.upper()

# %%
# Cambiar nombre de varias columnas en un solo llamado a rename
nuevos_nombres = {
    'ID': 'ID_HECHO',
    'FRANJA_HORA': 'HORA',
    'TIPO_CALLE': 'TIPO_DE_CALLE',
    'GEOCODIFICACION_CABA': 'XY (CABA)',
    'ACUSADO': 'VEHICULO_ACUSADO'
}

lesiones.rename(columns=nuevos_nombres, inplace=True)

# %%
lesiones
# Out:
#               ID_HECHO  N_VICTIMAS                FECHA  HORA COMUNA  \
# 0      LC-2019-0000179         1.0  2019-01-01 00:00:00   9.0     14
# 1      LC-2019-0000053         1.0  2019-01-01 00:00:00   1.0      8
# 2      LC-2019-0000063         1.0  2019-01-01 00:00:00   2.0      8
# 3      LC-2019-0000079         1.0  2019-01-01 00:00:00   2.0      7
# 4      LC-2019-0000082         4.0  2019-01-01 00:00:00   4.0      3
# ...                ...         ...                  ...   ...    ...
# 23780  LC-2021-0652849         1.0  2021-12-31 00:00:00  19.0      9
# 23781  LC-2021-0652865         2.0  2021-12-31 00:00:00  19.0      9
# 23782  LC-2021-0652907         1.0  2021-12-31 00:00:00  20.0      1
# 23783  LC-2021-0652921         1.0  2021-12-31 00:00:00  22.0      5
# 23784  LC-2020-0244615         1.0            5/17/2020  21.0    NaN
#
#       TIPO_DE_CALLE                                          XY (CABA)  \
# 0               NaN  Point (104991.46333918849995825 107720.9664748...
# 1               NaN  Point (101813.84712503915943671 95578.55507230...
# 2               NaN  Point (99538.58660300650808495 94643.418717990...
# 3               NaN  Point (102372.16830963784013875 97994.13750300...
# 4               NaN  Point (105968.98286849579017144 102737.1734686...
# ...             ...                                                ...
# 23780       AVENIDA          Point (95400.5441905024 96621.6007711877)
# 23781       AVENIDA          Point (97705.4491469278 98614.8825470092)
# 23782           NaN  Point (107377.10694920316745993 105120.7873965...
# 23783         CALLE          Point (104472.702045632 101660.930364258)
# 23784           NaN  Point (114990.04979284359433223 88934.67755418...
#
#            LONGITUD       LATUTID    VEHICULO_ACUSADO GRAVEDAD
# 0     -5.840891e+01 -3.455966e+01                 NaN      NaN
# 1     -5.844351e+01 -3.466913e+01                 NaN      NaN
# 2     -5.846834e+01 -3.467756e+01                 NaN      NaN
# 3     -5.843742e+01 -3.464735e+01                 NaN      NaN
# 4     -5.839822e+01 -3.460458e+01                 NaN      NaN
# ...             ...           ...                 ...      ...
# 23780 -5.851348e+01 -3.465971e+01                 NaN      NaN
# 23781 -5.848833e+01 -3.464175e+01                 NaN      NaN
# 23782 -5.838289e+01 -3.458308e+01                 NaN      NaN
# 23783 -5.841453e+01 -3.461429e+01  TRANSPORTE PUBLICO    GRAVE
# 23784 -5.829963e+09 -3.472891e+09                AUTO      NaN
#
# [23785 rows x 11 columns]

# %%
# Hacer cambios en la columna 'FECHA'
lesiones['FECHA'] = pd.to_datetime(lesiones['FECHA'].str.replace("'", ""), format='%y/%m/%d', errors='coerce').dt.date

# Reemplazar "No especificada" por nulos en la columna 'COMUNA'
lesiones['COMUNA'].replace('No Especificada', np.nan, inplace=True)

# Añadir gravedad 'LEVEMENTE HERIDO' a las filas con 'GRAVEDAD' nulo
lesiones['GRAVEDAD'].fillna('LEVEMENTE HERIDO', inplace=True)

# %%
lesiones
# Out:
#               ID_HECHO  N_VICTIMAS FECHA  HORA  COMUNA TIPO_DE_CALLE  \
# 0      LC-2019-0000179         1.0   NaT   9.0    14.0           NaN
# 1      LC-2019-0000053         1.0   NaT   1.0     8.0           NaN
# 2      LC-2019-0000063         1.0   NaT   2.0     8.0           NaN
# 3      LC-2019-0000079         1.0   NaT   2.0     7.0           NaN
# 4      LC-2019-0000082         4.0   NaT   4.0     3.0           NaN
# ...                ...         ...   ...   ...     ...           ...
# 23780  LC-2021-0652849         1.0   NaT  19.0     9.0       AVENIDA
# 23781  LC-2021-0652865         2.0   NaT  19.0     9.0       AVENIDA
# 23782  LC-2021-0652907         1.0   NaT  20.0     1.0           NaN
# 23783  LC-2021-0652921         1.0   NaT  22.0     5.0         CALLE
# 23784  LC-2020-0244615         1.0   NaT  21.0     NaN           NaN
#
#                                                XY (CABA)      LONGITUD  \
# 0      Point (104991.46333918849995825 107720.9664748... -5.840891e+01
# 1      Point (101813.84712503915943671 95578.55507230... -5.844351e+01
# 2      Point (99538.58660300650808495 94643.418717990... -5.846834e+01
# 3      Point (102372.16830963784013875 97994.13750300... -5.843742e+01
# 4      Point (105968.98286849579017144 102737.1734686... -5.839822e+01
# ...                                                  ...           ...
# 23780          Point (95400.5441905024 96621.6007711877) -5.851348e+01
# 23781          Point (97705.4491469278 98614.8825470092) -5.848833e+01
# 23782  Point (107377.10694920316745993 105120.7873965... -5.838289e+01
# 23783          Point (104472.702045632 101660.930364258) -5.841453e+01
# 23784  Point (114990.04979284359433223 88934.67755418... -5.829963e+09
#
#             LATUTID    VEHICULO_ACUSADO          GRAVEDAD
# 0     -3.455966e+01                 NaN  LEVEMENTE HERIDO
# 1     -3.466913e+01                 NaN  LEVEMENTE HERIDO
# 2     -3.467756e+01                 NaN  LEVEMENTE HERIDO
# 3     -3.464735e+01                 NaN  LEVEMENTE HERIDO
# 4     -3.460458e+01                 NaN  LEVEMENTE HERIDO
# ...             ...                 ...               ...
# 23780 -3.465971e+01                 NaN  LEVEMENTE HERIDO
# 23781 -3.464175e+01                 NaN  LEVEMENTE HERIDO
# 23782 -3.458308e+01                 NaN  LEVEMENTE HERIDO
# 23783 -3.461429e+01  TRANSPORTE PUBLICO             GRAVE
# 23784 -3.472891e+09                AUTO  LEVEMENTE HERIDO
#
# [23785 rows x 11 columns]

# %% [markdown]
# Ahora vamos con el sub archivo

# %%
# Cambiar el nombre de las columnas y estandarizarlas
nuevos_nombres = {'ID_hecho': 'ID_HECHO', 'ROL': 'ROL_VICTIMA', 'VICTIMA': 'VEHICULO_VICTIMA',
                  'SEXO': 'SEXO_VICTIMA', "EDAD": "EDAD_VICTIMA"}

# Cambiar el nombre de la columna 'EDAD'
vic_les.rename(columns={"EDAD": "EDAD_VICTIMA"}, inplace=True)

# Remplazar nombres de columnas
vic_les.rename(columns=nuevos_nombres, inplace=True)

# Mostrar las columnas del DataFrame después del cambio
vic_les.columns
# Out:
# Index(['ID hecho', 'AAA', 'MM', 'DD', 'FECHA ', 'VEHICULO_VICTIMA',
#        'SEXO_VICTIMA', 'EDAD_VICTIMA', 'GRAVEDAD'],
#       dtype='object')

# %%
vic_les
# Out:
#               ID hecho   AAA  MM  DD     FECHA     VEHICULO_VICTIMA  \
# 0      LC-2019-0000053  2019   1   1 2019-01-01                 NaN
# 1      LC-2019-0000063  2019   1   1 2019-01-01                 NaN
# 2      LC-2019-0000079  2019   1   1 2019-01-01                 NaN
# 3      LC-2019-0000082  2019   1   1 2019-01-01                 NaN
# 4      LC-2019-0000082  2019   1   1 2019-01-01                 NaN
# ...                ...   ...  ..  ..        ...                 ...
# 27600  LC-2021-0451911  2021   9  11 2021-09-11  TRANSPORTE PUBLICO
# 27601  LC-2021-0530228  2021  10  25 2021-10-25  TRANSPORTE PUBLICO
# 27602  LC-2021-0530228  2021  10  25 2021-10-25  TRANSPORTE PUBLICO
# 27603  LC-2021-0201378  2021   5   2 2021-05-02                MOTO
# 27604  LC-2021-0229350  2021   5  19 2021-05-19                MOTO
#
#       SEXO_VICTIMA  EDAD_VICTIMA GRAVEDAD
# 0            Varon          57.0      NaN
# 1              NaN           NaN      NaN
# 2            Varon           NaN      NaN
# 3            Varon          45.0      NaN
# 4            Mujer          45.0      NaN
# ...            ...           ...      ...
# 27600        Varon          87.0      NaN
# 27601        Mujer          60.0      NaN
# 27602        Mujer          32.0      NaN
# 27603        Varon          32.0      NaN
# 27604        Varon          41.0      NaN
#
# [27605 rows x 9 columns]

# %%
# Cambia el formato de la columna 'FECHA'
vic_les['FECHA'] = pd.to_datetime(vic_les['FECHA'], errors='coerce').dt.date

# %%
vic_les.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27605 entries, 0 to 27604
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID hecho          27605 non-null  object
#  1   AAA               27605 non-null  int64
#  2   MM                27605 non-null  int64
#  3   DD                27605 non-null  int64
#  4   FECHA             27605 non-null  datetime64[ns]
#  5   VEHICULO_VICTIMA  11333 non-null  object
#  6   SEXO_VICTIMA      25377 non-null  object
#  7   EDAD_VICTIMA      23134 non-null  float64
#  8   GRAVEDAD          537 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# Exportamos nuestro archivos

# %%
lesiones.to_csv("../Limpios/Lesiones.csv")
vic_les.to_csv("../Limpios/VictimasLesiones.csv")

# %% [markdown]
# ## Motociclistas

# %% [markdown]
# Armamos un nuevo dataframe únicamente con las victimas "moto" para nuestro kpi

# %%
vic_hom
# Out:
#       ID_hecho      FECHA                   ROL VICTIMA       SEXO  EDAD  \
# 0    2016-0001 2016-01-01             CONDUCTOR    MOTO  MASCULINO  19.0
# 1    2016-0002 2016-01-02             CONDUCTOR    AUTO  MASCULINO  70.0
# 2    2016-0003 2016-01-03             CONDUCTOR    MOTO  MASCULINO  30.0
# 3    2016-0004 2016-01-10             CONDUCTOR    MOTO  MASCULINO  18.0
# 4    2016-0005 2016-01-21             CONDUCTOR    MOTO  MASCULINO  29.0
# ..         ...        ...                   ...     ...        ...   ...
# 712  2021-0092 2021-12-12                PEATON  PEATON   FEMENINO  50.0
# 713  2021-0093 2021-12-13  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  18.0
# 714  2021-0094 2021-12-20  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  43.0
# 715  2021-0095 2021-12-30             CONDUCTOR    MOTO  MASCULINO  27.0
# 716  2021-0096 2021-12-15             CONDUCTOR    AUTO  MASCULINO  60.0
#
#     GRAVEDAD
# 0      FATAL
# 1      FATAL
# 2      FATAL
# 3      FATAL
# 4      FATAL
# ..       ...
# 712    FATAL
# 713    FATAL
# 714    FATAL
# 715    FATAL
# 716    FATAL
#
# [717 rows x 7 columns]

# %%
df_moto = vic_hom[vic_hom['VICTIMA'].str.contains(r'moto', case=False, na=False, regex=True)]

# %%
df_moto
# Out:
#       ID_hecho      FECHA                   ROL VICTIMA       SEXO  EDAD  \
# 0    2016-0001 2016-01-01             CONDUCTOR    MOTO  MASCULINO  19.0
# 2    2016-0003 2016-01-03             CONDUCTOR    MOTO  MASCULINO  30.0
# 3    2016-0004 2016-01-10             CONDUCTOR    MOTO  MASCULINO  18.0
# 4    2016-0005 2016-01-21             CONDUCTOR    MOTO  MASCULINO  29.0
# 5    2016-0008 2016-01-24             CONDUCTOR    MOTO  MASCULINO  30.0
# ..         ...        ...                   ...     ...        ...   ...
# 709  2021-0089 2021-12-02             CONDUCTOR    MOTO  MASCULINO  41.0
# 711  2021-0091 2021-12-11             CONDUCTOR    MOTO  MASCULINO  24.0
# 713  2021-0093 2021-12-13  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  18.0
# 714  2021-0094 2021-12-20  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO  43.0
# 715  2021-0095 2021-12-30             CONDUCTOR    MOTO  MASCULINO  27.0
#
#     GRAVEDAD
# 0      FATAL
# 2      FATAL
# 3      FATAL
# 4      FATAL
# 5      FATAL
# ..       ...
# 709    FATAL
# 711    FATAL
# 713    FATAL
# 714    FATAL
# 715    FATAL
#
# [303 rows x 7 columns]
